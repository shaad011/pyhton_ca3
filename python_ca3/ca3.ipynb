# %% [markdown]
# # Python CA-3

# %%
import pandas as pd

# %% [markdown]
# ### Q1

# %%
df = pd.read_csv("IPL IMB381IPL2013.csv")

# %% [markdown]
# ### Q2

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %% [markdown]
# ### Q3

# %%
print("Metadata of dataset :\n")
df.info()

print("\nShape of DataFrame:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)
# Out:
# Metadata of dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %% [markdown]
# ### Q4

# %%
print("\nSummary of dataset:")
print(df.describe())
# Out:
# Summary of dataset:
#            Sl.NO.         AGE        T-RUNS      T-WKTS    ODI-RUNS-S  \
# count  130.000000  130.000000    130.000000  130.000000    130.000000
# mean    65.500000    2.092308   2166.715385   66.530769   2508.738462
# std     37.671829    0.576627   3305.646757  142.676855   3582.205625
# min      1.000000    1.000000      0.000000    0.000000      0.000000
# 25%     33.250000    2.000000     25.500000    0.000000     73.250000
# 50%     65.500000    2.000000    542.500000    7.000000    835.000000
# 75%     97.750000    2.000000   3002.250000   47.500000   3523.500000
# max    130.000000    3.000000  15470.000000  800.000000  18426.000000
#
#          ODI-SR-B    ODI-WKTS   ODI-SR-BL  CAPTAINCY EXP       RUNS-S  ...  \
# count  130.000000  130.000000  130.000000     130.000000   130.000000  ...
# mean    71.164385   76.076923   34.033846       0.315385   514.246154  ...
# std     25.898440  111.205070   26.751749       0.466466   615.226335  ...
# ...

# %% [markdown]
# ### Q5

# %%
print("\nSelecting row with index label 5:")
print(df.loc[5])

print("\nSelecting rows with index labels from 0 to 4:")
print(df.loc[0:4])  

print("\nSelecting rows by integer position (first 3 rows):")
print(df.iloc[0:3])    

print("\nSlicing rows from index 10 to 15:")
print(df[10:15])
# Out:
# Selecting row with index label 5:
# Sl.NO.                    6
# PLAYER NAME      Bailey, GJ
# AGE                       2
# COUNTRY                 AUS
# TEAM                    CSK
# PLAYING ROLE        Batsman
# T-RUNS                    0
# T-WKTS                    0
# ODI-RUNS-S              172
# ODI-SR-B              72.26
# ODI-WKTS                  0
# ODI-SR-BL               0.0
# CAPTAINCY EXP             1
# RUNS-S                   63
# HS                       48
# AVE                    21.0
# SR-B                  95.45
# SIXERS                    0
# RUNS-C                    0
# WKTS                      0
# AVE-BL                  0.0
# ECON                    0.0
# SR-BL                   0.0
# AUCTION YEAR           2009
# BASE PRICE            50000
# SOLD PRICE            50000
# Name: 5, dtype: object
#
# Selecting rows with index labels from 0 to 4:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# ...

# %% [markdown]
# ### Q6

# %%
print("\nSelecting a single column 'TEAM':")
print(df['TEAM'])

print("\nSelecting multiple columns 'TEAM' and 'COUNTRY':")
print(df[['TEAM', 'COUNTRY']])
# Out:
# Selecting a single column 'TEAM':
# 0       KXIP
# 1        RCB
# 2        KKR
# 3        CSK
# 4        CSK
#        ...
# 125       DC
# 126       RR
# 127    KXIP+
# 128      MI+
# 129       DC
# Name: TEAM, Length: 130, dtype: object
#
# Selecting multiple columns 'TEAM' and 'COUNTRY':
#       TEAM COUNTRY
# 0     KXIP      SA
# 1      RCB     BAN
# 2      KKR     IND
# 3      CSK     IND
# 4      CSK     IND
# ..     ...     ...
# 125     DC     IND
# 126     RR     PAK
# 127  KXIP+     IND
# 128    MI+     IND
# 129     DC      SL
#
# [130 rows x 2 columns]

# %% [markdown]
# ### Q7

# %%
unique_countries = df['COUNTRY'].unique()
print("\nUnique countries:")
print(unique_countries)
# Out:
# Unique countries:
# ['SA' 'BAN' 'IND' 'AUS' 'WI' 'SL' 'NZ' 'ENG' 'PAK' 'ZIM']

# %% [markdown]
# ### Q8

# %%
crosstab_result = pd.crosstab(df['AGE'], df['PLAYING ROLE'], margins=True, margins_name="Total")
print("\nCross-tabulation between AGE and PLAYING ROLE:")
crosstab_result
# Out:
# Cross-tabulation between AGE and PLAYING ROLE:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper  Total
# AGE
# 1                      4        5       7          0     16
# 2                     25       21      29         11     86
# 3                      6       13       8          1     28
# Total                 35       39      44         12    130

# %% [markdown]
# ### Q9

# %%
sorted_df = df.sort_values(by='SOLD PRICE', ascending=False)
sorted_df
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 93       94      Sehwag, V    2     IND     DD      Batsman    8178      40
# 127     128   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 50       51       Kohli, V    1     IND    RCB      Batsman     491       0
# 111     112  Tendulkar, SR    3     IND     MI      Batsman   15470      45
# 113     114     Tiwary, SS    1     IND    MI+      Batsman       0       0
# ..      ...            ...  ...     ...    ...          ...     ...     ...
# 34       35  Henriques, MC    1     AUS   KKR+   Allrounder       0       0
# 5         6     Bailey, GJ    2     AUS    CSK      Batsman       0       0
# 0         1    Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 46       47    Kamran Khan    1     IND    RR+       Bowler       0       0
# 73       74     Noffke, AA    2     AUS    RCB   Allrounder       0       0
#
# ...

# %%
sorted_df = df.sort_values(by='PLAYING ROLE', ascending=True)
sorted_df
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 99      100    Shoaib Malik    2     PAK     DD   Allrounder    1606      21
# 26       27       Gayle, CH    2      WI   KKR+   Allrounder    6373      72
# 61       62    McDonald, AB    2     AUS    DD+   Allrounder     107       9
# 102     103       Smith, DR    2      WI    DC+   Allrounder     320       7
# ..      ...             ...  ...     ...    ...          ...     ...     ...
# 9        10     Boucher, MV    2      SA   RCB+    W. Keeper    5515       1
# 75       76        Ojha, NV    2     IND    RR+    W. Keeper       0       0
# 91       92  Sangakkara, KC    2      SL  KXIP+    W. Keeper    9382       0
# 90       91        Saha, WP    2     IND   KKR+    W. Keeper      74       0
# 60       61    McCullum, BB    2      NZ   KKR+    W. Keeper    3763       0
#
# ...

# %% [markdown]
# ### Q10

# %%
df['PREMIUM'] = df['SOLD PRICE'] - df['BASE PRICE']
max_premium_player = df.loc[df['PREMIUM'].idxmax()]
print("\nPlayer with the maximum premium:")
print(f"Player Name: {max_premium_player['PLAYER NAME']}")
print(f"Sold Price: {max_premium_player['SOLD PRICE']}")
print(f"Base Price: {max_premium_player['BASE PRICE']}")
print(f"Premium: {max_premium_player['PREMIUM']}")
# Out:
# Player with the maximum premium:
# Player Name: Kohli, V
# Sold Price: 1800000
# Base Price: 150000
# Premium: 1650000

# %% [markdown]
# ### Q11

# %%
max_premium_value = df['PREMIUM'].max()

max_premium_players = df[df['PREMIUM'] == max_premium_value]

print("\nPlayers with the maximum premium:")
for index, player in max_premium_players.iterrows():
    print(f"Player Name: {player['PLAYER NAME']}, Sold Price: {player['SOLD PRICE']}, Base Price: {player['BASE PRICE']}, Premium: {player['PREMIUM']}\n")
# Out:
# Players with the maximum premium:
# Player Name: Kohli, V, Sold Price: 1800000, Base Price: 150000, Premium: 1650000

# %% [markdown]
# ### Q12

# %%
filtered_df = df[df['AGE'].isin([1, 2, 3])]
average_sold_price1 = filtered_df.groupby('AGE')['SOLD PRICE'].mean().reset_index()

print("Average SOLD PRICE for each age (1, 2, 3):")
average_sold_price1
# Out:
# Average SOLD PRICE for each age (1, 2, 3):
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %% [markdown]
# ### Q13

# %%
average_sold_price2 = filtered_df.groupby(['AGE', 'PLAYING ROLE'])['SOLD PRICE'].mean().reset_index()
print("Average SOLD PRICE for different playing roles in ages 1, 2, and 3:")
pd.set_option('display.float_format', '{:.2f}'.format)
average_sold_price2
# Out:
# Average SOLD PRICE for different playing roles in ages 1, 2, and 3:
#     AGE PLAYING ROLE  SOLD PRICE
# 0     1   Allrounder   587500.00
# 1     1      Batsman  1110000.00
# 2     1       Bowler   517714.29
# 3     2   Allrounder   449400.00
# 4     2      Batsman   654761.90
# 5     2       Bowler   397931.03
# 6     2    W. Keeper   467727.27
# 7     3   Allrounder   766666.67
# 8     3      Batsman   457692.31
# 9     3       Bowler   414375.00
# 10    3    W. Keeper   700000.00
